# %%
#Generate the 2D data using the following piece of code:

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_moons
Xmoon , ymoon = make_moons(300, noise= 0.08, random_state = 0)
plt.scatter(Xmoon[:, 0], Xmoon[:,1])

# %%
# Build a clustering instance using Gaussian Mixture Model to cluster the above data in two clusters

# %%
from sklearn.mixture import GaussianMixture as GMM

# %%
gmm = GMM(n_components=2, covariance_type='full', random_state=0)
gmm.fit(Xmoon)
labels = gmm.predict(Xmoon)
plt.scatter(Xmoon[:, 0], Xmoon[:,1], c =labels, s =40, cmap= 'viridis')

# %%
# As in the above model we can easily defined that node equal to 2 is taking centriod which might noth give the correct clustering and have noise.

# %%
# for identifying clear boundaries 
from scipy.spatial.distance import cdist
from matplotlib.patches import Ellipse 
gmm = GMM(n_components=4)
plot_gmm(gmm,Xmoon)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-49-9760ba0afbe2> in <module>
#       3 from matplotlib.patches import Ellipse
#       4 gmm = GMM(n_components=4)
# ----> 5 plot_gmm(gmm,Xmoon)
#
# <ipython-input-40-8654a20de06c> in plot_gmm(gmm, X, label, ax)
#      29
#      30     w_factor = 0.2 / gmm.weights_.max()
# ---> 31     for pos, covars_, w in zip(gmm.means_, gmm.covars_, gmm.weights_):
#      32         draw_ellipse(pos, covars_, alpha=w * w_factor)
#
# AttributeError: 'GaussianMixture' object has no attribute 'covars_'

# %%
gmm = GMM(n_components=4, random_state=42)
plot_gmm(gmm, Xmoon)

# %%
from sklearn.cluster import KMeans
from scipy.spatial.distance import cdist

def plot_kmeans(kmeans, X, n_clusters=2, rseed=0, ax=None):
    labels = kmeans.fit_predict(X)

    # plot the input data
    ax = ax or plt.gca()
    ax.axis('equal')
    ax.scatter(X[:, 0], X[:, 1], c=labels, s=40, cmap='viridis', zorder=2)

    # plot the representation of the KMeans model
    centers = kmeans.cluster_centers_
    radii = [cdist(X[labels == i], [center]).max()
             for i, center in enumerate(centers)]
    for c, r in zip(centers, radii):
        ax.add_patch(plt.Circle(c, r, fc='#CCCCCC', lw=3, alpha=0.5, zorder=1))

# %%
kmeans = KMeans(n_clusters=2, random_state=0)
plot_kmeans(kmeans, Xmoon)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_moons
Xmoon , ymoon = make_moons(100, noise= 0.08, random_state = 0)
plt.scatter(Xmoon[:, 0], Xmoon[:,1])

# %%
kmeans = KMeans(n_clusters=2, random_state=0)
plot_kmeans(kmeans, Xmoon)

# %%
kmeans = KMeans(n_clusters=8, random_state=0)
plot_kmeans(kmeans, Xmoon)

# %%
gmm = GMM(n_components=2, covariance_type='full', random_state=0)
gmm.fit(Xmoon)
labels = gmm.predict(Xmoon)
plt.scatter(Xmoon[:, 0], Xmoon[:,1], c =labels, s =40, cmap= 'viridis')

# %%
gmm = GMM(n_components=4, covariance_type='full', random_state=0)
gmm.fit(Xmoon)
labels = gmm.predict(Xmoon)
plt.scatter(Xmoon[:, 0], Xmoon[:,1], c =labels, s =40, cmap= 'viridis')

# %%
# To decide no of components calculate the AIC and BIC createria

# %%
n_components = np.arange(1, 21)
models = [GMM(n, covariance_type='full', random_state=0).fit(Xmoon)
          for n in n_components]

plt.plot(n_components, [m.bic(Xmoon) for m in models], label='BIC')
plt.plot(n_components, [m.aic(Xmoon) for m in models], label='AIC')
plt.legend(loc='best')
plt.xlabel('n_components');
# Out:
# G:\anaconda\lib\site-packages\sklearn\cluster\_kmeans.py:881: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
gmm = GMM(n_components=6, covariance_type='full', random_state=0)
gmm.fit(Xmoon)
labels = gmm.predict(Xmoon)
plt.scatter(Xmoon[:, 0], Xmoon[:,1], c =labels, s =40, cmap= 'viridis')

# %%
# 6 component is the better choice
